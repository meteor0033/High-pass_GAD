# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(1, 2, figsize=(12, 4))


#T-Social
x = [1, 2, 3, 4, 5,6,7]
#40% F1 
y1 = [56.78, 76.24, 94.37, 93.67,  94.84, 94.93,93.36]
#40% auc
y2 = [72.43, 92.60, 98.11, 98.22, 98.58, 98.94,98.49]

#1% F1 
y3 = [56.67, 86.53, 90.30, 94.17,  93.74, 94.39,92.33]
#1% auc
y4 = [70.96, 95.58, 97.18, 98.38, 97.84, 98.58,98.21]
plt.subplot(1,2,1),
plt.plot(x,y1,marker='v', mfc='w')
plt.plot(x,y2,marker='v', mfc='w')

plt.plot(x,y3,marker='*', mfc='w')
plt.plot(x,y4,marker='*', mfc='w')
plt.ylabel(r"$F1-Macro\ or\ AUC\ \left(\%\right)$")
#plt.ylabel(r"$T-Social\left(\%\right)$")
plt.xlabel("K")
plt.title("T-Social")
         
axes[0].legend(['40% F1-Macro', '40% AUC', '1% F1-Macro', '1% AUC'], 
               ncol=2,                     # 每行 2 个图例项
               loc='lower right')

# 提取第一个子图的轴范围
#xlim = axes[0].get_xlim()
ylim = axes[0].get_ylim()
 
# 将这些范围应用到第二个子图的轴上
#axes[1].set_xlim(xlim)
axes[1].set_ylim(ylim)

#T-Finance
x = [1, 2, 3, 4, 5]
#40% F1 
y1 = [86.05, 91.29, 91.13, 90.00, 90.65]
#40% auc
y2 = [92.29, 96.69, 96.46, 94.80, 95.98]
#1% F1 
y3 = [84.61, 85.36, 88.21, 85.52, 84.64]
#1% auc
y4 = [91.08, 91.09, 93.23, 91.60, 89.13]
plt.subplot(1,2,2),
plt.plot(x,y1,marker='v',mfc='w')
plt.plot(x,y2,marker='v', mfc='w')
plt.plot(x,y3,marker='*', mfc='w')
plt.plot(x,y4,marker='*', mfc='w')
plt.ylabel(r"$F1-Macro\ or\ AUC\ \left(\%\right)$")
#plt.ylabel(r"$T-Finance\left(\%\right)$")
plt.xlabel("K")
plt.title("T-Finance")
#plt.legend(['40% F1-Macro','40% AUC','1% F1-Macro','1% AUC'],bbox_to_anchor=(0,1),loc=4, ncol=2,mode="expand", borderaxespad=0)
axes[1].legend(['40% F1-Macro', '40% AUC', '1% F1-Macro', '1% AUC'],
               ncol=2,                     # 每行 2 个图例项
               loc='lower right')

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
plt.subplot(1,2,1)
#T-finiance time
x = [1, 2, 3, 4, 5]
#40% time 
y1 = [147, 691, 1237, 1780, 2292]
#1% tiem 
y2 = [149, 677, 1239, 1808, 2370]
plt.plot(x,y1,marker='v',mfc='w')
plt.plot(x,y2,marker='v', mfc='w')
plt.legend(['40%','1%'], loc=2)
plt.ylabel(r"$Time\  consumption\left(s\right)$")
plt.xlabel("K")
plt.title("T-Finance")

#T-Social time
plt.subplot(1,2,2),
x = [1, 2, 3, 4, 5, 6,7]
#40% time 
y1 = [2270, 4403, 6579, 8428, 11001, 13027,15278]
#1% tiem 
y2 = [3372, 5438, 7647, 9338, 11231,13324,16347]
plt.plot(x,y1,marker='v',mfc='w')
plt.plot(x,y2,marker='v',mfc='w')
plt.ylabel(r"$Time\  consumption\left(s\right)$")
plt.xlabel("K")
plt.title("T-Social")
            
plt.legend(['40%','1%'], loc=2)
