# %% [markdown]
# # model source
# ### Training CARE-GNN
# ### Paper: Enhancing Graph Neural Network-based Fraud Detectors against Camouflaged Fraudsters
# ### Source: https://github.com/YingtongDou/CARE-GNN

# %%
import dgl
import torch
import torch.nn.functional as F
# 其中包括激活函数, 损失函数, 池化函数 ,通过 F.xxx() 的形式，可以方便地调用 torch.nn.functional 模块中的各种函数
import numpy
import argparse
import time
from dataset_process.dataset import Dataset
from sklearn.metrics import f1_score, accuracy_score, recall_score, roc_auc_score, precision_score, confusion_matrix
from model.CAREGNN_anomaly import *
from sklearn.model_selection import train_test_split
from layers.CAREGNN_layers import *
from collections import defaultdict

# %%
def train(model, g, args):
    features = g.ndata['feature']
    labels = g.ndata['label']
    index = list(range(len(labels)))
    if dataset_name == 'amazon':
        index = list(range(3305, len(labels)))

    idx_train, idx_rest, y_train, y_rest = train_test_split(index, labels[index], stratify=labels[index],
                                                            train_size=args.train_ratio,
                                                            random_state=2, shuffle=True)
    idx_valid, idx_test, y_valid, y_test = train_test_split(idx_rest, y_rest, stratify=y_rest,
                                                            test_size=0.67,
                                                            random_state=2, shuffle=True)
    train_mask = torch.zeros([len(labels)]).bool()
    val_mask = torch.zeros([len(labels)]).bool()
    test_mask = torch.zeros([len(labels)]).bool()

    train_mask[idx_train] = 1
    val_mask[idx_valid] = 1
    test_mask[idx_test] = 1
    print('train/dev/test samples: ', train_mask.sum().item(), val_mask.sum().item(), test_mask.sum().item())
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    best_f1, final_tf1, final_trec, final_tpre, final_tmf1, final_tauc = 0., 0., 0., 0., 0., 0.

    weight = (1-labels[train_mask]).sum().item() / labels[train_mask].sum().item()
    print('cross entropy weight: ', weight)
    time_start = time.time()
    for e in range(args.epoch):
        # 训练
        model.train()
        # 调用模型中的forward函数
        logits = model(features)
        loss = F.cross_entropy(logits[train_mask], labels[train_mask], weight=torch.tensor([1., weight]))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #验证
        model.eval()
        probs = logits.softmax(1)
        f1, thres = get_best_f1(labels[val_mask], probs[val_mask])
        preds = numpy.zeros_like(labels)
        preds[probs[:, 1] > thres] = 1
        trec = recall_score(labels[test_mask], preds[test_mask])
        tpre = precision_score(labels[test_mask], preds[test_mask])
        tmf1 = f1_score(labels[test_mask], preds[test_mask], average='macro')
        tauc = roc_auc_score(labels[test_mask], probs[test_mask][:, 1].detach().numpy())

        if best_f1 < f1:
            best_f1 = f1
            final_trec = trec
            final_tpre = tpre
            final_tmf1 = tmf1
            final_tauc = tauc
        print('Epoch {}, loss: {:.4f}, val mf1: {:.4f}, (best {:.4f})'.format(e, loss, f1, best_f1))

    time_end = time.time()
    print('time cost: ', time_end - time_start, 's')
    print('Test: REC {:.2f} PRE {:.2f} MF1 {:.2f} AUC {:.2f}'.format(final_trec*100,
                                                                     final_tpre*100, final_tmf1*100, final_tauc*100))
    return final_tmf1, final_tauc


# threshold adjusting for best macro f1
def get_best_f1(labels, probs):
    best_f1, best_thre = 0, 0
    for thres in np.linspace(0.05, 0.95, 19):
        #构建一个与labels同维度的数组,并初始化所有变量为零
        preds = np.zeros_like(labels)
        preds[probs[:,1] > thres] = 1
        #average='binary'：计算二分类问题中的 F1 分数（默认值）。
        #average='micro'：对所有类别的真实和预测样本进行汇总，然后计算 F1 分数。
        #average='macro'：计算每个类别的 F1 分数，然后取平均值。
        #average=None：返回每个类别的 F1 分数。
        # F1_score 详细原理间“备份”
        mf1 = f1_score(labels, preds, average='macro')
        if mf1 > best_f1:
            best_f1 = mf1
            best_thre = thres
    return best_f1, best_thre

# %%
parser = argparse.ArgumentParser(description='CAREGNN_GAD')
parser.add_argument("--dataset", type=str, default="yelp",
                        help="Dataset for this model (yelp/amazon/tfinance/tsocial)")
parser.add_argument("--train_ratio", type=float, default=0.10, help="Training ratio")
parser.add_argument("--hid_dim", type=int, default=64, help="Hidden layer dimension")
parser.add_argument("--homo", type=int, default=0, help="1 for CAREGNN_GAD(Homo) and 0 for CAREGNN_GAD(Hetero)")
parser.add_argument("--epoch", type=int, default=100, help="The max number of epochs")
parser.add_argument("--run", type=int, default=1, help="Running times")
parser.add_argument('--lambda_1', type=float, default=2, help='Simi loss weight.')
parser.add_argument('--no-cuda', action='store_true', default=False, help='Disables CUDA training.')
parser.add_argument('--emb-size', type=int, default=64, help='Node embedding size at the last layer.')
parser.add_argument('--inter', type=str, default='GNN', help='The inter-relation aggregator type. [Att, Weight, Mean, GNN]')
parser.add_argument('--step-size', type=float, default=2e-2, help='RL action step size')
parser.add_argument('--model', type=str, default='CARE', help='The model name. [CARE, SAGE]')

args = parser.parse_args(args = [])
args.cuda = not args.no_cuda and torch.cuda.is_available()

print(args)
dataset_name = args.dataset
homo = args.homo
h_feats = args.hid_dim
graph = Dataset(dataset_name, homo).graph
#edge_index = Dataset(dataset_name, homo).edge_index
# Out:
# Namespace(dataset='yelp', train_ratio=0.1, hid_dim=64, order=2, homo=0, epoch=100, run=1, k=3, lambda_1=2, no_cuda=False, emb_size=64, inter='GNN', step_size=0.02, model='CARE', cuda=False)
# Done loading data from cached files.
# Graph(num_nodes={'review': 45954},
#       num_edges={('review', 'net_rsr', 'review'): 6805486, ('review', 'net_rtr', 'review'): 1147232, ('review', 'net_rur', 'review'): 98630},
#       metagraph=[('review', 'review', 'net_rsr'), ('review', 'review', 'net_rtr'), ('review', 'review', 'net_rur')])

# %%
graph['net_rur'].num_nodes()
# Out:
# 45954

# %%
###################################################################################
############        从 DGL 图中获取图节点的邻居
##################################################################################
if (homo):
    adj_lists = defaultdict(set)
    # 获取每个节点的邻居节点并存储为 frozenset
    for node in range(graph.num_nodes()):
        neighbors = graph.successors(node)  # 对于出边邻居，使用 successors
        for value in neighbors.tolist():
            adj_lists[node].add(value)  
else: ## only (dataset_name =='yelp') || (dataset_name =='yelp')
    adj_list0 = defaultdict(set)
    # 获取每个节点的邻居节点并存储为 frozenset
    for node in range(graph[graph.canonical_etypes[0]].num_nodes()):
        neighbors = graph[graph.canonical_etypes[0]].successors(node)  # 对于出边邻居，使用 successors
        for value in neighbors.tolist():
            adj_list0[node].add(value)
                
    adj_list1 = defaultdict(set)
    # 获取每个节点的邻居节点并存储为 frozenset
    for node in range(graph[graph.canonical_etypes[1]].num_nodes()):
        neighbors = graph[graph.canonical_etypes[1]].successors(node)  # 对于出边邻居，使用 successors
        for value in neighbors.tolist():
            adj_list1[node].add(value)
        
    adj_list2 = defaultdict(set)
    # 获取每个节点的邻居节点并存储为 frozenset
    for node in range(graph[graph.canonical_etypes[2]].num_nodes()):
        neighbors = graph[graph.canonical_etypes[2]].successors(node)  # 对于出边邻居，使用 successors
        for value in neighbors.tolist():
            adj_list2[node].add(value)
    
    adj_lists = [adj_list0, adj_list1, adj_list2]
# Out:
# Node 10 has neighbors sets: {11}
# Node 11 has neighbors sets: {10}
# Node 14 has neighbors sets: {15}
# Node 15 has neighbors sets: {14}
# Node 17 has neighbors sets: {18}
# Node 18 has neighbors sets: {17}
# Node 29 has neighbors sets: {30}
# Node 30 has neighbors sets: {29}
# Node 32 has neighbors sets: {33}
# Node 33 has neighbors sets: {32}
# Node 38 has neighbors sets: {39}
# Node 39 has neighbors sets: {38}
# Node 43 has neighbors sets: {44, 45}
# Node 44 has neighbors sets: {43, 45}
# Node 45 has neighbors sets: {43, 44}
# Node 46 has neighbors sets: {48, 49, 47}
# Node 47 has neighbors sets: {48, 49, 46}
# Node 48 has neighbors sets: {49, 46, 47}
# Node 49 has neighbors sets: {48, 46, 47}
# Node 56 has neighbors sets: {57, 58}
# Node 57 has neighbors sets: {56, 58}
# Node 58 has neighbors sets: {56, 57}
# Node 59 has neighbors sets: {60}
# Node 60 has neighbors sets: {59}
# Node 62 has neighbors sets: {63}
# Node 63 has neighbors sets: {62}
# Node 64 has neighbors sets: {65, 66}
# Node 65 has neighbors sets: {64, 66}
# Node 66 has neighbors sets: {64, 65}
# Node 67 has neighbors sets: {68}
# Node 68 has neighbors sets: {67}
# Node 75 has neighbors sets: {76, 77, 78, 79, 80}
# Node 76 has neighbors sets: {75, 77, 78, 79, 80}
# Node 77 has neighbors sets: {75, 76, 78, 79, 80}
# Node 78 has neighbors sets: {75, 76, 77, 79, 80}
# Node 79 has neighbors sets: {75, 76, 77, 78, 80}
# Node 80 has neighbors sets: {75, 76, 77, 78, 79}
# Node 81 has neighbors sets: {82}
# Node 82 has neighbors sets: {81}
# Node 83 has neighbors sets: {84, 85, 86, 87, 88, 89, 90, 91}
# Node 84 has neighbors sets: {83, 85, 86, 87, 88, 89, 90, 91}
# Node 85 has neighbors sets: {83, 84, 86, 87, 88, 89, 90, 91}
# Node 86 has neighbors sets: {83, 84, 85, 87, 88, 89, 90, 91}
# Node 87 has neighbors sets: {83, 84, 85, 86, 88, 89, 90, 91}
# Node 88 has neighbors sets: {83, 84, 85, 86, 87, 89, 90, 91}
# Node 89 has neighbors sets: {83, 84, 85, 86, 87, 88, 90, 91}
# Node 90 has neighbors sets: {83, 84, 85, 86, 87, 88, 89, 91}
# Node 91 has neighbors sets: {83, 84, 85, 86, 87, 88, 89, 90}
# Node 93 has neighbors sets: {94}
# Node 94 has neighbors sets: {93}
# Node 95 has neighbors sets: {96, 97}
# Node 96 has neighbors sets: {97, 95}
# Node 97 has neighbors sets: {96, 95}
# Node 98 has neighbors sets: {99, 100, 101, 102, 103, 104, 105, 106, 107, 108}
# Node 99 has neighbors sets: {98, 100, 101, 102, 103, 104, 105, 106, 107, 108}
# Node 100 has neighbors sets: {98, 99, 101, 102, 103, 104, 105, 106, 107, 108}
# Node 101 has neighbors sets: {98, 99, 100, 102, 103, 104, 105, 106, 107, 108}
# Node 102 has neighbors sets: {98, 99, 100, 101, 103, 104, 105, 106, 107, 108}
# Node 103 has neighbors sets: {98, 99, 100, 101, 102, 104, 105, 106, 107, 108}
# Node 104 has neighbors sets: {98, 99, 100, 101, 102, 103, 105, 106, 107, 108}
# Node 105 has neighbors sets: {98, 99, 100, 101, 102, 103, 104, 106, 107, 108}
# Node 106 has neighbors sets: {98, 99, 100, 101, 102, 103, 104, 105, 107, 108}
# Node 107 has neighbors sets: {98, 99, 100, 101, 102, 103, 104, 105, 106, 108}
# Node 108 has neighbors sets: {98, 99, 100, 101, 102, 103, 104, 105, 106, 107}
# Node 109 has neighbors sets: {110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 110 has neighbors sets: {109, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 111 has neighbors sets: {109, 110, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 112 has neighbors sets: {109, 110, 111, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 113 has neighbors sets: {109, 110, 111, 112, 114, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 114 has neighbors sets: {109, 110, 111, 112, 113, 115, 116, 117, 118, 119, 120, 121, 122}
# Node 115 has neighbors sets: {109, 110, 111, 112, 113, 114, 116, 117, 118, 119, 120, 121, 122}
# Node 116 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 117, 118, 119, 120, 121, 122}
# Node 117 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 118, 119, 120, 121, 122}
# Node 118 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 117, 119, 120, 121, 122}
# Node 119 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 120, 121, 122}
# Node 120 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 121, 122}
# Node 121 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 122}
# Node 122 has neighbors sets: {109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121}
# Node 123 has neighbors sets: {124}
# Node 124 has neighbors sets: {123}
# Node 127 has neighbors sets: {128, 129}
# Node 128 has neighbors sets: {129, 127}
# Node 129 has neighbors sets: {128, 127}
# Node 130 has neighbors sets: {131, 132, 133}
# Node 131 has neighbors sets: {130, 132, 133}
# Node 132 has neighbors sets: {130, 131, 133}
# Node 133 has neighbors sets: {130, 131, 132}
# Node 134 has neighbors sets: {135}
# Node 135 has neighbors sets: {134}
# Node 138 has neighbors sets: {139}
# Node 139 has neighbors sets: {138}
# Node 140 has neighbors sets: {141, 142}
# Node 141 has neighbors sets: {140, 142}
# Node 142 has neighbors sets: {140, 141}
# Node 143 has neighbors sets: {144, 145, 146, 147}
# Node 144 has neighbors sets: {145, 146, 147, 143}
# Node 145 has neighbors sets: {144, 146, 147, 143}
# Node 146 has neighbors sets: {144, 145, 147, 143}
# Node 147 has neighbors sets: {144, 145, 146, 143}
# Node 153 has neighbors sets: {154, 155, 156, 157}
# Node 154 has neighbors sets: {153, 155, 156, 157}
# Node 155 has neighbors sets: {153, 154, 156, 157}
# Node 156 has neighbors sets: {153, 154, 155, 157}
# Node 157 has neighbors sets: {153, 154, 155, 156}
# Node 160 has neighbors sets: {161}
# Node 161 has neighbors sets: {160}
# Node 163 has neighbors sets: {164, 165, 166, 167, 168, 169, 170}
# Node 164 has neighbors sets: {163, 165, 166, 167, 168, 169, 170}
# Node 165 has neighbors sets: {163, 164, 166, 167, 168, 169, 170}
# Node 166 has neighbors sets: {163, 164, 165, 167, 168, 169, 170}
# Node 167 has neighbors sets: {163, 164, 165, 166, 168, 169, 170}
# Node 168 has neighbors sets: {163, 164, 165, 166, 167, 169, 170}
# Node 169 has neighbors sets: {163, 164, 165, 166, 167, 168, 170}
# Node 170 has neighbors sets: {163, 164, 165, 166, 167, 168, 169}
# Node 179 has neighbors sets: {180}
# Node 180 has neighbors sets: {179}
# Node 181 has neighbors sets: {182}
# Node 182 has neighbors sets: {181}
# Node 197 has neighbors sets: {198, 199}
# Node 198 has neighbors sets: {197, 199}
# Node 199 has neighbors sets: {197, 198}
# Node 200 has neighbors sets: {201}
# Node 201 has neighbors sets: {200}
# Node 205 has neighbors sets: {206}
# Node 206 has neighbors sets: {205}
# Node 208 has neighbors sets: {209}
# Node 209 has neighbors sets: {208}
# Node 212 has neighbors sets: {213}
# Node 213 has neighbors sets: {212}
# Node 221 has neighbors sets: {224, 225, 226, 222, 223}
# Node 222 has neighbors sets: {224, 225, 226, 221, 223}
# Node 223 has neighbors sets: {224, 225, 226, 221, 222}
# Node 224 has neighbors sets: {225, 226, 221, 222, 223}
# Node 225 has neighbors sets: {224, 226, 221, 222, 223}
# Node 226 has neighbors sets: {224, 225, 221, 222, 223}
# Node 230 has neighbors sets: {232, 231}
# Node 231 has neighbors sets: {232, 230}
# Node 232 has neighbors sets: {230, 231}
# Node 239 has neighbors sets: {240, 241}
# Node 240 has neighbors sets: {241, 239}
# Node 241 has neighbors sets: {240, 239}
# Node 245 has neighbors sets: {246}
# Node 246 has neighbors sets: {245}
# Node 249 has neighbors sets: {250}
# Node 250 has neighbors sets: {249}
# Node 253 has neighbors sets: {254}
# Node 254 has neighbors sets: {253}
# Node 257 has neighbors sets: {258, 259, 260, 261, 262}
# Node 258 has neighbors sets: {257, 259, 260, 261, 262}
# Node 259 has neighbors sets: {257, 258, 260, 261, 262}
# Node 260 has neighbors sets: {257, 258, 259, 261, 262}
# Node 261 has neighbors sets: {257, 258, 259, 260, 262}
# Node 262 has neighbors sets: {257, 258, 259, 260, 261}
# Node 266 has neighbors sets: {267}
# Node 267 has neighbors sets: {266}
# Node 269 has neighbors sets: {270, 271, 272, 273, 274, 275, 276}
# Node 270 has neighbors sets: {269, 271, 272, 273, 274, 275, 276}
# Node 271 has neighbors sets: {269, 270, 272, 273, 274, 275, 276}
# Node 272 has neighbors sets: {269, 270, 271, 273, 274, 275, 276}
# Node 273 has neighbors sets: {269, 270, 271, 272, 274, 275, 276}
# Node 274 has neighbors sets: {269, 270, 271, 272, 273, 275, 276}
# Node 275 has neighbors sets: {269, 270, 271, 272, 273, 274, 276}
# Node 276 has neighbors sets: {269, 270, 271, 272, 273, 274, 275}
# Node 278 has neighbors sets: {279}
# Node 279 has neighbors sets: {278}
# Node 282 has neighbors sets: {283}
# Node 283 has neighbors sets: {282}
# Node 285 has neighbors sets: {288, 286, 287}
# Node 286 has neighbors sets: {288, 285, 287}
# Node 287 has neighbors sets: {288, 285, 286}
# Node 288 has neighbors sets: {285, 286, 287}
# Node 290 has neighbors sets: {291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 291 has neighbors sets: {290, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 292 has neighbors sets: {290, 291, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 293 has neighbors sets: {290, 291, 292, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 294 has neighbors sets: {290, 291, 292, 293, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 295 has neighbors sets: {290, 291, 292, 293, 294, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 296 has neighbors sets: {290, 291, 292, 293, 294, 295, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 297 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 298 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 299 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 300 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 301 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 302 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 303 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 304 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 305 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 306 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 307 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 308 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 309 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 310 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 311 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 312 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 313 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 314 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 315 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 316 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 317 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 318 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 319 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 320 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 321 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 322 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 323 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 324 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 325 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 326 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 327 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 328, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 328 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 329, 330, 331, 332, 333, 334, 335, 336}
# Node 329 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 330, 331, 332, 333, 334, 335, 336}
# Node 330 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 331, 332, 333, 334, 335, 336}
# Node 331 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 332, 333, 334, 335, 336}
# Node 332 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 333, 334, 335, 336}
# Node 333 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 334, 335, 336}
# Node 334 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 335, 336}
# Node 335 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 336}
# Node 336 has neighbors sets: {290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335}
# Node 337 has neighbors sets: {338, 339}
# Node 338 has neighbors sets: {337, 339}
# Node 339 has neighbors sets: {337, 338}
# Node 341 has neighbors sets: {344, 345, 342, 343}
# Node 342 has neighbors sets: {344, 345, 341, 343}
# Node 343 has neighbors sets: {344, 345, 341, 342}
# Node 344 has neighbors sets: {345, 341, 342, 343}
# Node 345 has neighbors sets: {344, 341, 342, 343}
# Node 351 has neighbors sets: {352}
# Node 352 has neighbors sets: {351}
# Node 354 has neighbors sets: {355}
# Node 355 has neighbors sets: {354}
# Node 358 has neighbors sets: {359}
# Node 359 has neighbors sets: {358}
# Node 360 has neighbors sets: {361, 362, 363}
# Node 361 has neighbors sets: {360, 362, 363}
# Node 362 has neighbors sets: {360, 361, 363}
# Node 363 has neighbors sets: {360, 361, 362}
# Node 369 has neighbors sets: {370}
# Node 370 has neighbors sets: {369}
# Node 373 has neighbors sets: {374, 375}
# Node 374 has neighbors sets: {373, 375}
# Node 375 has neighbors sets: {373, 374}
# Node 376 has neighbors sets: {377}
# Node 377 has neighbors sets: {376}
# Node 379 has neighbors sets: {380, 381, 382}
# Node 380 has neighbors sets: {379, 381, 382}
# Node 381 has neighbors sets: {379, 380, 382}
# Node 382 has neighbors sets: {379, 380, 381}
# Node 383 has neighbors sets: {384, 385}
# Node 384 has neighbors sets: {385, 383}
# Node 385 has neighbors sets: {384, 383}
# Node 387 has neighbors sets: {388, 389, 390, 391, 392, 393, 394, 395, 396}
# Node 388 has neighbors sets: {387, 389, 390, 391, 392, 393, 394, 395, 396}
# Node 389 has neighbors sets: {387, 388, 390, 391, 392, 393, 394, 395, 396}
# Node 390 has neighbors sets: {387, 388, 389, 391, 392, 393, 394, 395, 396}
# Node 391 has neighbors sets: {387, 388, 389, 390, 392, 393, 394, 395, 396}
# Node 392 has neighbors sets: {387, 388, 389, 390, 391, 393, 394, 395, 396}
# Node 393 has neighbors sets: {387, 388, 389, 390, 391, 392, 394, 395, 396}
# Node 394 has neighbors sets: {387, 388, 389, 390, 391, 392, 393, 395, 396}
# Node 395 has neighbors sets: {387, 388, 389, 390, 391, 392, 393, 394, 396}
# Node 396 has neighbors sets: {387, 388, 389, 390, 391, 392, 393, 394, 395}
# Node 398 has neighbors sets: {400, 399}
# Node 399 has neighbors sets: {400, 398}
# Node 400 has neighbors sets: {398, 399}
# Node 401 has neighbors sets: {402}
# Node 402 has neighbors sets: {401}
# Node 408 has neighbors sets: {409, 410, 411, 412}
# Node 409 has neighbors sets: {408, 410, 411, 412}
# Node 410 has neighbors sets: {408, 409, 411, 412}
# Node 411 has neighbors sets: {408, 409, 410, 412}
# Node 412 has neighbors sets: {408, 409, 410, 411}
# Node 414 has neighbors sets: {416, 417, 415}
# Node 415 has neighbors sets: {416, 417, 414}
# Node 416 has neighbors sets: {417, 414, 415}
# Node 417 has neighbors sets: {416, 414, 415}
# Node 418 has neighbors sets: {419}
# Node 419 has neighbors sets: {418}
# Node 421 has neighbors sets: {422}
# Node 422 has neighbors sets: {421}
# Node 424 has neighbors sets: {425, 426}
# Node 425 has neighbors sets: {424, 426}
# Node 426 has neighbors sets: {424, 425}
# Node 431 has neighbors sets: {432}
# Node 432 has neighbors sets: {431}
# Node 434 has neighbors sets: {435}
# Node 435 has neighbors sets: {434}
# Node 436 has neighbors sets: {448, 449, 450, 451, 452, 453, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 437 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 438 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 439 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 440 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 441, 442, 443, 444, 445, 446, 447}
# Node 441 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 442, 443, 444, 445, 446, 447}
# Node 442 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 443, 444, 445, 446, 447}
# Node 443 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 444, 445, 446, 447}
# Node 444 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 445, 446, 447}
# Node 445 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 446, 447}
# Node 446 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 447}
# Node 447 has neighbors sets: {448, 449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446}
# Node 448 has neighbors sets: {449, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 449 has neighbors sets: {448, 450, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 450 has neighbors sets: {448, 449, 451, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 451 has neighbors sets: {448, 449, 450, 452, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 452 has neighbors sets: {448, 449, 450, 451, 453, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 453 has neighbors sets: {448, 449, 450, 451, 452, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447}
# Node 455 has neighbors sets: {456, 457}
# Node 456 has neighbors sets: {457, 455}
# Node 457 has neighbors sets: {456, 455}
# Node 459 has neighbors sets: {460, 461, 462, 463, 464}
# Node 460 has neighbors sets: {459, 461, 462, 463, 464}
# Node 461 has neighbors sets: {459, 460, 462, 463, 464}
# Node 462 has neighbors sets: {459, 460, 461, 463, 464}
# Node 463 has neighbors sets: {459, 460, 461, 462, 464}
# Node 464 has neighbors sets: {459, 460, 461, 462, 463}
# Node 471 has neighbors sets: {472}
# Node 472 has neighbors sets: {471}
# Node 473 has neighbors sets: {474}
# Node 474 has neighbors sets: {473}
# Node 475 has neighbors sets: {476}
# Node 476 has neighbors sets: {475}
# Node 477 has neighbors sets: {478}
# Node 478 has neighbors sets: {477}
# Node 483 has neighbors sets: {484}
# Node 484 has neighbors sets: {483}
# Node 488 has neighbors sets: {489, 490}
# Node 489 has neighbors sets: {488, 490}
# Node 490 has neighbors sets: {488, 489}
# Node 493 has neighbors sets: {496, 494, 495}
# Node 494 has neighbors sets: {496, 493, 495}
# Node 495 has neighbors sets: {496, 493, 494}
# Node 496 has neighbors sets: {493, 494, 495}
# Node 497 has neighbors sets: {498, 499, 500, 501, 502, 503, 504, 505, 506}
# Node 498 has neighbors sets: {497, 499, 500, 501, 502, 503, 504, 505, 506}
# Node 499 has neighbors sets: {497, 498, 500, 501, 502, 503, 504, 505, 506}
# Node 500 has neighbors sets: {497, 498, 499, 501, 502, 503, 504, 505, 506}
# Node 501 has neighbors sets: {497, 498, 499, 500, 502, 503, 504, 505, 506}
# Node 502 has neighbors sets: {497, 498, 499, 500, 501, 503, 504, 505, 506}
# Node 503 has neighbors sets: {497, 498, 499, 500, 501, 502, 504, 505, 506}
# Node 504 has neighbors sets: {497, 498, 499, 500, 501, 502, 503, 505, 506}
# Node 505 has neighbors sets: {497, 498, 499, 500, 501, 502, 503, 504, 506}
# Node 506 has neighbors sets: {497, 498, 499, 500, 501, 502, 503, 504, 505}
# Node 513 has neighbors sets: {514}
# Node 514 has neighbors sets: {513}
# Node 515 has neighbors sets: {516, 517}
# Node 516 has neighbors sets: {515, 517}
# Node 517 has neighbors sets: {515, 516}
# Node 518 has neighbors sets: {519}
# Node 519 has neighbors sets: {518}
# Node 521 has neighbors sets: {522}
# Node 522 has neighbors sets: {521}
# Node 525 has neighbors sets: {526, 527}
# Node 526 has neighbors sets: {525, 527}
# Node 527 has neighbors sets: {525, 526}
# Node 533 has neighbors sets: {534}
# Node 534 has neighbors sets: {533}
# Node 537 has neighbors sets: {538}
# Node 538 has neighbors sets: {537}
# Node 540 has neighbors sets: {541, 542, 543}
# Node 541 has neighbors sets: {540, 542, 543}
# Node 542 has neighbors sets: {540, 541, 543}
# Node 543 has neighbors sets: {540, 541, 542}
# Node 545 has neighbors sets: {546}
# Node 546 has neighbors sets: {545}
# Node 547 has neighbors sets: {548}
# Node 548 has neighbors sets: {547}
# Node 553 has neighbors sets: {554, 555}
# Node 554 has neighbors sets: {553, 555}
# Node 555 has neighbors sets: {553, 554}
# Node 569 has neighbors sets: {576, 577, 570, 571, 572, 573, 574, 575}
# Node 570 has neighbors sets: {576, 577, 569, 571, 572, 573, 574, 575}
# Node 571 has neighbors sets: {576, 577, 569, 570, 572, 573, 574, 575}
# Node 572 has neighbors sets: {576, 577, 569, 570, 571, 573, 574, 575}
# Node 573 has neighbors sets: {576, 577, 569, 570, 571, 572, 574, 575}
# Node 574 has neighbors sets: {576, 577, 569, 570, 571, 572, 573, 575}
# Node 575 has neighbors sets: {576, 577, 569, 570, 571, 572, 573, 574}
# Node 576 has neighbors sets: {577, 569, 570, 571, 572, 573, 574, 575}
# Node 577 has neighbors sets: {576, 569, 570, 571, 572, 573, 574, 575}
# Node 579 has neighbors sets: {580}
# Node 580 has neighbors sets: {579}
# Node 583 has neighbors sets: {584}
# Node 584 has neighbors sets: {583}
# Node 590 has neighbors sets: {592, 591}
# Node 591 has neighbors sets: {592, 590}
# Node 592 has neighbors sets: {590, 591}
# Node 600 has neighbors sets: {601}
# Node 601 has neighbors sets: {600}
# Node 606 has neighbors sets: {607}
# Node 607 has neighbors sets: {606}
# Node 615 has neighbors sets: {616, 617, 618, 619}
# Node 616 has neighbors sets: {617, 618, 619, 615}
# Node 617 has neighbors sets: {616, 618, 619, 615}
# Node 618 has neighbors sets: {616, 617, 619, 615}
# Node 619 has neighbors sets: {616, 617, 618, 615}
# Node 622 has neighbors sets: {623}
# Node 623 has neighbors sets: {622}
# Node 626 has neighbors sets: {627, 628, 629, 630}
# Node 627 has neighbors sets: {626, 628, 629, 630}
# Node 628 has neighbors sets: {626, 627, 629, 630}
# Node 629 has neighbors sets: {626, 627, 628, 630}
# Node 630 has neighbors sets: {626, 627, 628, 629}
# Node 631 has neighbors sets: {632, 633}
# Node 632 has neighbors sets: {633, 631}
# Node 633 has neighbors sets: {632, 631}
# Node 647 has neighbors sets: {648}
# Node 648 has neighbors sets: {647}
# Node 649 has neighbors sets: {650}
# Node 650 has neighbors sets: {649}
# Node 652 has neighbors sets: {653}
# Node 653 has neighbors sets: {652}
# Node 660 has neighbors sets: {664, 661, 662, 663}
# Node 661 has neighbors sets: {664, 660, 662, 663}
# Node 662 has neighbors sets: {664, 660, 661, 663}
# Node 663 has neighbors sets: {664, 660, 661, 662}
# Node 664 has neighbors sets: {660, 661, 662, 663}
# Node 665 has neighbors sets: {666}
# Node 666 has neighbors sets: {665}
# Node 671 has neighbors sets: {672}
# Node 672 has neighbors sets: {671}
# Node 676 has neighbors sets: {677}
# Node 677 has neighbors sets: {676}
# Node 681 has neighbors sets: {682}
# Node 682 has neighbors sets: {681}
# Node 686 has neighbors sets: {687}
# Node 687 has neighbors sets: {686}
# Node 688 has neighbors sets: {689}
# Node 689 has neighbors sets: {688}
# Node 690 has neighbors sets: {691, 692}
# Node 691 has neighbors sets: {690, 692}
# Node 692 has neighbors sets: {690, 691}
# Node 694 has neighbors sets: {695}
# Node 695 has neighbors sets: {694}
# Node 700 has neighbors sets: {701, 702, 703}
# Node 701 has neighbors sets: {700, 702, 703}
# Node 702 has neighbors sets: {700, 701, 703}
# Node 703 has neighbors sets: {700, 701, 702}
# Node 707 has neighbors sets: {708}
# Node 708 has neighbors sets: {707}
# Node 711 has neighbors sets: {712}
# Node 712 has neighbors sets: {711}
# Node 713 has neighbors sets: {714, 715, 716, 717, 718, 719, 720}
# Node 714 has neighbors sets: {713, 715, 716, 717, 718, 719, 720}
# Node 715 has neighbors sets: {713, 714, 716, 717, 718, 719, 720}
# Node 716 has neighbors sets: {713, 714, 715, 717, 718, 719, 720}
# Node 717 has neighbors sets: {713, 714, 715, 716, 718, 719, 720}
# Node 718 has neighbors sets: {713, 714, 715, 716, 717, 719, 720}
# Node 719 has neighbors sets: {713, 714, 715, 716, 717, 718, 720}
# Node 720 has neighbors sets: {713, 714, 715, 716, 717, 718, 719}
# Node 721 has neighbors sets: {722}
# Node 722 has neighbors sets: {721}
# Node 727 has neighbors sets: {728, 729, 730, 731}
# Node 728 has neighbors sets: {729, 730, 731, 727}
# Node 729 has neighbors sets: {728, 730, 731, 727}
# Node 730 has neighbors sets: {728, 729, 731, 727}
# Node 731 has neighbors sets: {728, 729, 730, 727}
# Node 732 has neighbors sets: {733, 734, 735}
# Node 733 has neighbors sets: {732, 734, 735}
# Node 734 has neighbors sets: {732, 733, 735}
# Node 735 has neighbors sets: {732, 733, 734}
# Node 736 has neighbors sets: {737, 738}
# Node 737 has neighbors sets: {736, 738}
# Node 738 has neighbors sets: {736, 737}
# Node 753 has neighbors sets: {754}
# Node 754 has neighbors sets: {753}
# Node 758 has neighbors sets: {760, 759}
# Node 759 has neighbors sets: {760, 758}
# Node 760 has neighbors sets: {758, 759}
# Node 761 has neighbors sets: {762, 763}
# Node 762 has neighbors sets: {761, 763}
# Node 763 has neighbors sets: {761, 762}
# Node 783 has neighbors sets: {784, 785, 786}
# Node 784 has neighbors sets: {785, 786, 783}
# Node 785 has neighbors sets: {784, 786, 783}
# Node 786 has neighbors sets: {784, 785, 783}
# Node 788 has neighbors sets: {789}
# Node 789 has neighbors sets: {788}
# Node 792 has neighbors sets: {793, 794, 795, 796}
# Node 793 has neighbors sets: {792, 794, 795, 796}
# Node 794 has neighbors sets: {792, 793, 795, 796}
# Node 795 has neighbors sets: {792, 793, 794, 796}
# Node 796 has neighbors sets: {792, 793, 794, 795}
# Node 797 has neighbors sets: {798, 799}
# Node 798 has neighbors sets: {797, 799}
# Node 799 has neighbors sets: {797, 798}
# Node 801 has neighbors sets: {802}
# Node 802 has neighbors sets: {801}
# Node 804 has neighbors sets: {805, 806, 807}
# Node 805 has neighbors sets: {804, 806, 807}
# Node 806 has neighbors sets: {804, 805, 807}
# Node 807 has neighbors sets: {804, 805, 806}
# Node 809 has neighbors sets: {810}
# Node 810 has neighbors sets: {809}
# Node 811 has neighbors sets: {812}
# Node 812 has neighbors sets: {811}
# Node 816 has neighbors sets: {817}
# Node 817 has neighbors sets: {816}
# Node 819 has neighbors sets: {820}
# Node 820 has neighbors sets: {819}
# Node 823 has neighbors sets: {824, 825, 826}
# Node 824 has neighbors sets: {825, 826, 823}
# Node 825 has neighbors sets: {824, 826, 823}
# Node 826 has neighbors sets: {824, 825, 823}
# Node 830 has neighbors sets: {832, 833, 834, 831}
# Node 831 has neighbors sets: {832, 833, 834, 830}
# Node 832 has neighbors sets: {833, 834, 830, 831}
# Node 833 has neighbors sets: {832, 834, 830, 831}
# Node 834 has neighbors sets: {832, 833, 830, 831}
# Node 837 has neighbors sets: {838}
# Node 838 has neighbors sets: {837}
# Node 843 has neighbors sets: {844, 845, 846}
# Node 844 has neighbors sets: {843, 845, 846}
# Node 845 has neighbors sets: {843, 844, 846}
# Node 846 has neighbors sets: {843, 844, 845}
# Node 847 has neighbors sets: {848}
# Node 848 has neighbors sets: {847}
# Node 849 has neighbors sets: {850}
# Node 850 has neighbors sets: {849}
# Node 851 has neighbors sets: {852}
# Node 852 has neighbors sets: {851}
# Node 855 has neighbors sets: {856, 857, 858, 859}
# Node 856 has neighbors sets: {857, 858, 859, 855}
# Node 857 has neighbors sets: {856, 858, 859, 855}
# Node 858 has neighbors sets: {856, 857, 859, 855}
# Node 859 has neighbors sets: {856, 857, 858, 855}
# Node 860 has neighbors sets: {861, 862}
# Node 861 has neighbors sets: {860, 862}
# Node 862 has neighbors sets: {860, 861}
# Node 863 has neighbors sets: {864, 865, 866}
# Node 864 has neighbors sets: {865, 866, 863}
# Node 865 has neighbors sets: {864, 866, 863}
# Node 866 has neighbors sets: {864, 865, 863}
# Node 872 has neighbors sets: {873}
# Node 873 has neighbors sets: {872}
# Node 874 has neighbors sets: {875, 876}
# Node 875 has neighbors sets: {874, 876}
# Node 876 has neighbors sets: {874, 875}
# Node 877 has neighbors sets: {878, 879}
# Node 878 has neighbors sets: {877, 879}
# Node 879 has neighbors sets: {877, 878}
# Node 884 has neighbors sets: {885}
# Node 885 has neighbors sets: {884}
# Node 887 has neighbors sets: {888}
# Node 888 has neighbors sets: {887}
# Node 889 has neighbors sets: {890, 891, 892, 893}
# Node 890 has neighbors sets: {889, 891, 892, 893}
# Node 891 has neighbors sets: {889, 890, 892, 893}
# Node 892 has neighbors sets: {889, 890, 891, 893}
# Node 893 has neighbors sets: {889, 890, 891, 892}
# Node 896 has neighbors sets: {897}
# Node 897 has neighbors sets: {896}
# Node 898 has neighbors sets: {899, 900}
# Node 899 has neighbors sets: {898, 900}
# Node 900 has neighbors sets: {898, 899}
# Node 902 has neighbors sets: {903}
# Node 903 has neighbors sets: {902}
# Node 913 has neighbors sets: {914, 915, 916, 917, 918, 919}
# Node 914 has neighbors sets: {913, 915, 916, 917, 918, 919}
# Node 915 has neighbors sets: {913, 914, 916, 917, 918, 919}
# Node 916 has neighbors sets: {913, 914, 915, 917, 918, 919}
# Node 917 has neighbors sets: {913, 914, 915, 916, 918, 919}
# Node 918 has neighbors sets: {913, 914, 915, 916, 917, 919}
# Node 919 has neighbors sets: {913, 914, 915, 916, 917, 918}
# Node 920 has neighbors sets: {921}
# Node 921 has neighbors sets: {920}
# Node 923 has neighbors sets: {924, 925}
# Node 924 has neighbors sets: {923, 925}
# Node 925 has neighbors sets: {923, 924}
# Node 934 has neighbors sets: {935}
# Node 935 has neighbors sets: {934}
# Node 939 has neighbors sets: {940}
# Node 940 has neighbors sets: {939}
# Node 942 has neighbors sets: {943}
# Node 943 has neighbors sets: {942}
# Node 948 has neighbors sets: {949}
# Node 949 has neighbors sets: {948}
# Node 951 has neighbors sets: {952}
# Node 952 has neighbors sets: {951}
# Node 953 has neighbors sets: {954}
# Node 954 has neighbors sets: {953}
# Node 967 has neighbors sets: {968, 969, 970, 971}
# Node 968 has neighbors sets: {969, 970, 971, 967}
# Node 969 has neighbors sets: {968, 970, 971, 967}
# Node 970 has neighbors sets: {968, 969, 971, 967}
# Node 971 has neighbors sets: {968, 969, 970, 967}
# Node 972 has neighbors sets: {973}
# Node 973 has neighbors sets: {972}
# Node 976 has neighbors sets: {977}
# Node 977 has neighbors sets: {976}
# Node 980 has neighbors sets: {981}
# Node 981 has neighbors sets: {980}
# Node 986 has neighbors sets: {987, 988}
# Node 987 has neighbors sets: {986, 988}
# Node 988 has neighbors sets: {986, 987}
# Node 999 has neighbors sets: {1000, 1001, 1002, 1003}
# Node 1000 has neighbors sets: {1001, 1002, 1003, 999}
# Node 1001 has neighbors sets: {1000, 1002, 1003, 999}
# Node 1002 has neighbors sets: {1000, 1001, 1003, 999}
# Node 1003 has neighbors sets: {1000, 1001, 1002, 999}
# Node 1010 has neighbors sets: {1011, 1012, 1013, 1014}
# Node 1011 has neighbors sets: {1010, 1012, 1013, 1014}
# Node 1012 has neighbors sets: {1010, 1011, 1013, 1014}
# Node 1013 has neighbors sets: {1010, 1011, 1012, 1014}
# Node 1014 has neighbors sets: {1010, 1011, 1012, 1013}
# Node 1020 has neighbors sets: {1021}
# Node 1021 has neighbors sets: {1020}
# Node 1024 has neighbors sets: {1025}
# Node 1025 has neighbors sets: {1024}
# Node 1032 has neighbors sets: {1033, 1034, 1035}
# Node 1033 has neighbors sets: {1032, 1034, 1035}
# Node 1034 has neighbors sets: {1032, 1033, 1035}
# Node 1035 has neighbors sets: {1032, 1033, 1034}
# Node 1037 has neighbors sets: {1038}
# Node 1038 has neighbors sets: {1037}
# Node 1041 has neighbors sets: {1042, 1043, 1044, 1045}
# Node 1042 has neighbors sets: {1041, 1043, 1044, 1045}
# Node 1043 has neighbors sets: {1041, 1042, 1044, 1045}
# Node 1044 has neighbors sets: {1041, 1042, 1043, 1045}
# Node 1045 has neighbors sets: {1041, 1042, 1043, 1044}
# Node 1049 has neighbors sets: {1050}
# Node 1050 has neighbors sets: {1049}
# Node 1052 has neighbors sets: {1053}
# Node 1053 has neighbors sets: {1052}
# Node 1062 has neighbors sets: {1063}
# Node 1063 has neighbors sets: {1062}
# Node 1064 has neighbors sets: {1065}
# Node 1065 has neighbors sets: {1064}
# Node 1067 has neighbors sets: {1068}
# Node 1068 has neighbors sets: {1067}
# Node 1069 has neighbors sets: {1070, 1071, 1072, 1073, 1074}
# Node 1070 has neighbors sets: {1069, 1071, 1072, 1073, 1074}
# Node 1071 has neighbors sets: {1069, 1070, 1072, 1073, 1074}
# Node 1072 has neighbors sets: {1069, 1070, 1071, 1073, 1074}
# Node 1073 has neighbors sets: {1069, 1070, 1071, 1072, 1074}
# Node 1074 has neighbors sets: {1069, 1070, 1071, 1072, 1073}
# Node 1077 has neighbors sets: {1078}
# Node 1078 has neighbors sets: {1077}
# Node 1082 has neighbors sets: {1083, 1084}
# Node 1083 has neighbors sets: {1082, 1084}
# Node 1084 has neighbors sets: {1082, 1083}
# Node 1087 has neighbors sets: {1088, 1089}
# Node 1088 has neighbors sets: {1089, 1087}
# Node 1089 has neighbors sets: {1088, 1087}
# Node 1091 has neighbors sets: {1092}
# Node 1092 has neighbors sets: {1091}
# Node 1093 has neighbors sets: {1094}
# Node 1094 has neighbors sets: {1093}
# Node 1096 has neighbors sets: {1097}
# Node 1097 has neighbors sets: {1096}
# Node 1102 has neighbors sets: {1104, 1103}
# Node 1103 has neighbors sets: {1104, 1102}
# Node 1104 has neighbors sets: {1102, 1103}
# Node 1108 has neighbors sets: {1109}
# Node 1109 has neighbors sets: {1108}
# Node 1115 has neighbors sets: {1116}
# Node 1116 has neighbors sets: {1115}
# Node 1118 has neighbors sets: {1120, 1121, 1119}
# Node 1119 has neighbors sets: {1120, 1121, 1118}
# Node 1120 has neighbors sets: {1121, 1118, 1119}
# Node 1121 has neighbors sets: {1120, 1118, 1119}
# Node 1122 has neighbors sets: {1123}
# Node 1123 has neighbors sets: {1122}
# Node 1125 has neighbors sets: {1126, 1127}
# Node 1126 has neighbors sets: {1125, 1127}
# Node 1127 has neighbors sets: {1125, 1126}
# Node 1128 has neighbors sets: {1129}
# Node 1129 has neighbors sets: {1128}
# Node 1130 has neighbors sets: {1131}
# Node 1131 has neighbors sets: {1130}
# Node 1137 has neighbors sets: {1138, 1139, 1140}
# Node 1138 has neighbors sets: {1137, 1139, 1140}
# Node 1139 has neighbors sets: {1137, 1138, 1140}
# Node 1140 has neighbors sets: {1137, 1138, 1139}
# Node 1146 has neighbors sets: {1147}
# Node 1147 has neighbors sets: {1146}
# Node 1153 has neighbors sets: {1154, 1155, 1156}
# Node 1154 has neighbors sets: {1153, 1155, 1156}
# Node 1155 has neighbors sets: {1153, 1154, 1156}
# Node 1156 has neighbors sets: {1153, 1154, 1155}
# Node 1157 has neighbors sets: {1160, 1161, 1158, 1159}
# Node 1158 has neighbors sets: {1160, 1161, 1157, 1159}
# Node 1159 has neighbors sets: {1160, 1161, 1157, 1158}
# Node 1160 has neighbors sets: {1161, 1157, 1158, 1159}
# Node 1161 has neighbors sets: {1160, 1157, 1158, 1159}
# Node 1165 has neighbors sets: {1166, 1167}
# Node 1166 has neighbors sets: {1165, 1167}
# Node 1167 has neighbors sets: {1165, 1166}
# Node 1171 has neighbors sets: {1172}
# Node 1172 has neighbors sets: {1171}
# Node 1173 has neighbors sets: {1176, 1177, 1174, 1175}
# Node 1174 has neighbors sets: {1176, 1177, 1173, 1175}
# Node 1175 has neighbors sets: {1176, 1177, 1173, 1174}
# Node 1176 has neighbors sets: {1177, 1173, 1174, 1175}
# Node 1177 has neighbors sets: {1176, 1173, 1174, 1175}
# Node 1184 has neighbors sets: {1185, 1186}
# Node 1185 has neighbors sets: {1184, 1186}
# Node 1186 has neighbors sets: {1184, 1185}
# Node 1187 has neighbors sets: {1188}
# Node 1188 has neighbors sets: {1187}
# Node 1189 has neighbors sets: {1190}
# Node 1190 has neighbors sets: {1189}
# Node 1197 has neighbors sets: {1200, 1198, 1199}
# Node 1198 has neighbors sets: {1200, 1197, 1199}
# Node 1199 has neighbors sets: {1200, 1197, 1198}
# Node 1200 has neighbors sets: {1197, 1198, 1199}
# Node 1208 has neighbors sets: {1209, 1210, 1211, 1212, 1213, 1214}
# Node 1209 has neighbors sets: {1208, 1210, 1211, 1212, 1213, 1214}
# Node 1210 has neighbors sets: {1208, 1209, 1211, 1212, 1213, 1214}
# Node 1211 has neighbors sets: {1208, 1209, 1210, 1212, 1213, 1214}
# Node 1212 has neighbors sets: {1208, 1209, 1210, 1211, 1213, 1214}
# Node 1213 has neighbors sets: {1208, 1209, 1210, 1211, 1212, 1214}
# Node 1214 has neighbors sets: {1208, 1209, 1210, 1211, 1212, 1213}
# Node 1215 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233}
# Node 1216 has neighbors sets: {1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1217 has neighbors sets: {1216, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1218 has neighbors sets: {1216, 1217, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1219 has neighbors sets: {1216, 1217, 1218, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1220 has neighbors sets: {1216, 1217, 1218, 1219, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1221 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1222 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1223 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1224 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1225 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1226 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1227 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1228, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1228 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1229, 1230, 1231, 1232, 1233, 1215}
# Node 1229 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1230, 1231, 1232, 1233, 1215}
# Node 1230 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1231, 1232, 1233, 1215}
# Node 1231 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1232, 1233, 1215}
# Node 1232 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1233, 1215}
# Node 1233 has neighbors sets: {1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1215}
# Node 1235 has neighbors sets: {1236}
# Node 1236 has neighbors sets: {1235}
# Node 1237 has neighbors sets: {1238}
# Node 1238 has neighbors sets: {1237}
# Node 1241 has neighbors sets: {1242, 1243, 1244, 1245, 1246}
# Node 1242 has neighbors sets: {1241, 1243, 1244, 1245, 1246}
# Node 1243 has neighbors sets: {1241, 1242, 1244, 1245, 1246}
# Node 1244 has neighbors sets: {1241, 1242, 1243, 1245, 1246}
# Node 1245 has neighbors sets: {1241, 1242, 1243, 1244, 1246}
# Node 1246 has neighbors sets: {1241, 1242, 1243, 1244, 1245}
# Node 1248 has neighbors sets: {1249, 1250, 1251}
# Node 1249 has neighbors sets: {1248, 1250, 1251}
# Node 1250 has neighbors sets: {1248, 1249, 1251}
# Node 1251 has neighbors sets: {1248, 1249, 1250}
# Node 1253 has neighbors sets: {1254}
# Node 1254 has neighbors sets: {1253}
# Node 1257 has neighbors sets: {1258}
# Node 1258 has neighbors sets: {1257}
# Node 1259 has neighbors sets: {1260, 1261}
# Node 1260 has neighbors sets: {1259, 1261}
# Node 1261 has neighbors sets: {1259, 1260}
# Node 1263 has neighbors sets: {1264, 1265, 1266}
# Node 1264 has neighbors sets: {1265, 1266, 1263}
# Node 1265 has neighbors sets: {1264, 1266, 1263}
# Node 1266 has neighbors sets: {1264, 1265, 1263}
# Node 1267 has neighbors sets: {1268}
# ...
# Node 42418 has neighbors sets: {42417}
# Node 42422 has neighbors sets: {42423}
# Node 42423 has neighbors sets: {42422}
# Node 42426 has neighbors sets: {42427}
# Node 42427 has neighbors sets: {42426}
# Node 42429 has neighbors sets: {42430}
# Node 42430 has neighbors sets: {42429}
# Node 42433 has neighbors sets: {42434}
# Node 42434 has neighbors sets: {42433}
# Node 42441 has neighbors sets: {42442}
# Node 42442 has neighbors sets: {42441}
# Node 42454 has neighbors sets: {42455}
# Node 42455 has neighbors sets: {42454}
# Node 42474 has neighbors sets: {42475}
# Node 42475 has neighbors sets: {42474}
# Node 42484 has neighbors sets: {42485}
# Node 42485 has neighbors sets: {42484}
# Node 42498 has neighbors sets: {42499, 42500, 42501, 42502, 42503, 42504}
# Node 42499 has neighbors sets: {42498, 42500, 42501, 42502, 42503, 42504}
# Node 42500 has neighbors sets: {42498, 42499, 42501, 42502, 42503, 42504}
# Node 42501 has neighbors sets: {42498, 42499, 42500, 42502, 42503, 42504}
# Node 42502 has neighbors sets: {42498, 42499, 42500, 42501, 42503, 42504}
# Node 42503 has neighbors sets: {42498, 42499, 42500, 42501, 42502, 42504}
# Node 42504 has neighbors sets: {42498, 42499, 42500, 42501, 42502, 42503}
# Node 42522 has neighbors sets: {42523}
# Node 42523 has neighbors sets: {42522}
# Node 42524 has neighbors sets: {42525, 42526}
# Node 42525 has neighbors sets: {42524, 42526}
# Node 42526 has neighbors sets: {42524, 42525}
# Node 42527 has neighbors sets: {42528, 42529}
# Node 42528 has neighbors sets: {42529, 42527}
# Node 42529 has neighbors sets: {42528, 42527}
# Node 42530 has neighbors sets: {42531, 42532, 42533}
# Node 42531 has neighbors sets: {42530, 42532, 42533}
# Node 42532 has neighbors sets: {42530, 42531, 42533}
# Node 42533 has neighbors sets: {42530, 42531, 42532}
# Node 42540 has neighbors sets: {42541}
# Node 42541 has neighbors sets: {42540}
# Node 42545 has neighbors sets: {42546}
# Node 42546 has neighbors sets: {42545}
# Node 42561 has neighbors sets: {42562}
# Node 42562 has neighbors sets: {42561}
# Node 42567 has neighbors sets: {42568}
# Node 42568 has neighbors sets: {42567}
# Node 42575 has neighbors sets: {42576}
# Node 42576 has neighbors sets: {42575}
# Node 42581 has neighbors sets: {42582}
# Node 42582 has neighbors sets: {42581}
# Node 42585 has neighbors sets: {42586}
# Node 42586 has neighbors sets: {42585}
# Node 42588 has neighbors sets: {42589}
# Node 42589 has neighbors sets: {42588}
# Node 42596 has neighbors sets: {42597}
# Node 42597 has neighbors sets: {42596}
# Node 42599 has neighbors sets: {42600}
# Node 42600 has neighbors sets: {42599}
# Node 42602 has neighbors sets: {42603}
# Node 42603 has neighbors sets: {42602}
# Node 42615 has neighbors sets: {42616}
# Node 42616 has neighbors sets: {42615}
# Node 42627 has neighbors sets: {42628}
# Node 42628 has neighbors sets: {42627}
# Node 42630 has neighbors sets: {42631}
# Node 42631 has neighbors sets: {42630}
# Node 42641 has neighbors sets: {42642}
# Node 42642 has neighbors sets: {42641}
# Node 42662 has neighbors sets: {42663}
# Node 42663 has neighbors sets: {42662}
# Node 42668 has neighbors sets: {42669, 42670}
# Node 42669 has neighbors sets: {42668, 42670}
# Node 42670 has neighbors sets: {42668, 42669}
# Node 42674 has neighbors sets: {42675}
# Node 42675 has neighbors sets: {42674}
# Node 42691 has neighbors sets: {42692}
# Node 42692 has neighbors sets: {42691}
# Node 42702 has neighbors sets: {42703}
# Node 42703 has neighbors sets: {42702}
# Node 42712 has neighbors sets: {42713}
# Node 42713 has neighbors sets: {42712}
# Node 42717 has neighbors sets: {42718}
# Node 42718 has neighbors sets: {42717}
# Node 42720 has neighbors sets: {42721}
# Node 42721 has neighbors sets: {42720}
# Node 42734 has neighbors sets: {42736, 42737, 42738, 42735}
# Node 42735 has neighbors sets: {42736, 42737, 42738, 42734}
# Node 42736 has neighbors sets: {42737, 42738, 42734, 42735}
# Node 42737 has neighbors sets: {42736, 42738, 42734, 42735}
# Node 42738 has neighbors sets: {42736, 42737, 42734, 42735}
# Node 42743 has neighbors sets: {42744}
# Node 42744 has neighbors sets: {42743}
# Node 42746 has neighbors sets: {42747, 42748}
# Node 42747 has neighbors sets: {42746, 42748}
# Node 42748 has neighbors sets: {42746, 42747}
# Node 42749 has neighbors sets: {42750}
# Node 42750 has neighbors sets: {42749}
# Node 42761 has neighbors sets: {42762, 42763}
# Node 42762 has neighbors sets: {42761, 42763}
# Node 42763 has neighbors sets: {42761, 42762}
# Node 42765 has neighbors sets: {42766}
# Node 42766 has neighbors sets: {42765}
# Node 42774 has neighbors sets: {42775}
# Node 42775 has neighbors sets: {42774}
# Node 42782 has neighbors sets: {42783}
# Node 42783 has neighbors sets: {42782}
# Node 42786 has neighbors sets: {42787}
# Node 42787 has neighbors sets: {42786}
# Node 42810 has neighbors sets: {42811}
# Node 42811 has neighbors sets: {42810}
# Node 42819 has neighbors sets: {42820, 42821}
# Node 42820 has neighbors sets: {42819, 42821}
# Node 42821 has neighbors sets: {42819, 42820}
# Node 42825 has neighbors sets: {42826}
# Node 42826 has neighbors sets: {42825}
# Node 42830 has neighbors sets: {42831}
# Node 42831 has neighbors sets: {42830}
# Node 42840 has neighbors sets: {42841}
# Node 42841 has neighbors sets: {42840}
# Node 42859 has neighbors sets: {42860}
# Node 42860 has neighbors sets: {42859}
# Node 42863 has neighbors sets: {42864}
# Node 42864 has neighbors sets: {42863}
# Node 42869 has neighbors sets: {42870}
# Node 42870 has neighbors sets: {42869}
# Node 42873 has neighbors sets: {42874}
# Node 42874 has neighbors sets: {42873}
# Node 42927 has neighbors sets: {42928}
# Node 42928 has neighbors sets: {42927}
# Node 42943 has neighbors sets: {42944}
# Node 42944 has neighbors sets: {42943}
# Node 42951 has neighbors sets: {42952}
# Node 42952 has neighbors sets: {42951}
# Node 42957 has neighbors sets: {42958}
# Node 42958 has neighbors sets: {42957}
# Node 42975 has neighbors sets: {42976, 42977}
# Node 42976 has neighbors sets: {42977, 42975}
# Node 42977 has neighbors sets: {42976, 42975}
# Node 42991 has neighbors sets: {42992}
# Node 42992 has neighbors sets: {42991}
# Node 43019 has neighbors sets: {43020}
# Node 43020 has neighbors sets: {43019}
# Node 43036 has neighbors sets: {43037}
# Node 43037 has neighbors sets: {43036}
# Node 43060 has neighbors sets: {43061}
# Node 43061 has neighbors sets: {43060}
# Node 43091 has neighbors sets: {43092}
# Node 43092 has neighbors sets: {43091}
# Node 43121 has neighbors sets: {43122}
# Node 43122 has neighbors sets: {43121}
# Node 43132 has neighbors sets: {43133}
# Node 43133 has neighbors sets: {43132}
# Node 43139 has neighbors sets: {43140}
# Node 43140 has neighbors sets: {43139}
# Node 43145 has neighbors sets: {43146}
# Node 43146 has neighbors sets: {43145}
# Node 43219 has neighbors sets: {43220}
# Node 43220 has neighbors sets: {43219}
# Node 43224 has neighbors sets: {43225}
# Node 43225 has neighbors sets: {43224}
# Node 43234 has neighbors sets: {43235}
# Node 43235 has neighbors sets: {43234}
# Node 43239 has neighbors sets: {43240}
# Node 43240 has neighbors sets: {43239}
# Node 43242 has neighbors sets: {43243}
# Node 43243 has neighbors sets: {43242}
# Node 43249 has neighbors sets: {43250}
# Node 43250 has neighbors sets: {43249}
# Node 43251 has neighbors sets: {43252}
# Node 43252 has neighbors sets: {43251}
# Node 43274 has neighbors sets: {43275}
# Node 43275 has neighbors sets: {43274}
# Node 43288 has neighbors sets: {43289}
# Node 43289 has neighbors sets: {43288}
# Node 43295 has neighbors sets: {43296, 43297}
# Node 43296 has neighbors sets: {43297, 43295}
# Node 43297 has neighbors sets: {43296, 43295}
# Node 43335 has neighbors sets: {43336}
# Node 43336 has neighbors sets: {43335}
# Node 43339 has neighbors sets: {43340}
# Node 43340 has neighbors sets: {43339}
# Node 43353 has neighbors sets: {43354}
# Node 43354 has neighbors sets: {43353}
# Node 43356 has neighbors sets: {43357}
# Node 43357 has neighbors sets: {43356}
# Node 43360 has neighbors sets: {43361}
# Node 43361 has neighbors sets: {43360}
# Node 43399 has neighbors sets: {43400}
# Node 43400 has neighbors sets: {43399}
# Node 43401 has neighbors sets: {43402, 43403}
# Node 43402 has neighbors sets: {43401, 43403}
# Node 43403 has neighbors sets: {43401, 43402}
# Node 43407 has neighbors sets: {43408}
# Node 43408 has neighbors sets: {43407}
# Node 43409 has neighbors sets: {43410}
# Node 43410 has neighbors sets: {43409}
# Node 43444 has neighbors sets: {43445, 43446}
# Node 43445 has neighbors sets: {43444, 43446}
# Node 43446 has neighbors sets: {43444, 43445}
# Node 43485 has neighbors sets: {43486}
# Node 43486 has neighbors sets: {43485}
# Node 43492 has neighbors sets: {43493}
# Node 43493 has neighbors sets: {43492}
# Node 43521 has neighbors sets: {43522}
# Node 43522 has neighbors sets: {43521}
# Node 43535 has neighbors sets: {43536}
# Node 43536 has neighbors sets: {43535}
# Node 43558 has neighbors sets: {43559}
# Node 43559 has neighbors sets: {43558}
# Node 43598 has neighbors sets: {43599}
# Node 43599 has neighbors sets: {43598}
# Node 43602 has neighbors sets: {43603, 43604}
# Node 43603 has neighbors sets: {43602, 43604}
# Node 43604 has neighbors sets: {43602, 43603}
# Node 43630 has neighbors sets: {43631}
# Node 43631 has neighbors sets: {43630}
# Node 43648 has neighbors sets: {43649}
# Node 43649 has neighbors sets: {43648}
# Node 43687 has neighbors sets: {43688, 43689}
# Node 43688 has neighbors sets: {43689, 43687}
# Node 43689 has neighbors sets: {43688, 43687}
# Node 43707 has neighbors sets: {43708}
# Node 43708 has neighbors sets: {43707}
# Node 43713 has neighbors sets: {43714}
# Node 43714 has neighbors sets: {43713}
# Node 43716 has neighbors sets: {43717}
# Node 43717 has neighbors sets: {43716}
# Node 43765 has neighbors sets: {43766}
# Node 43766 has neighbors sets: {43765}
# Node 43776 has neighbors sets: {43777}
# Node 43777 has neighbors sets: {43776}
# Node 43780 has neighbors sets: {43781}
# Node 43781 has neighbors sets: {43780}
# Node 43795 has neighbors sets: {43796}
# Node 43796 has neighbors sets: {43795}
# Node 43800 has neighbors sets: {43801}
# Node 43801 has neighbors sets: {43800}
# Node 43808 has neighbors sets: {43809}
# Node 43809 has neighbors sets: {43808}
# Node 43819 has neighbors sets: {43820}
# Node 43820 has neighbors sets: {43819}
# Node 43823 has neighbors sets: {43824}
# Node 43824 has neighbors sets: {43823}
# Node 43834 has neighbors sets: {43835, 43836}
# Node 43835 has neighbors sets: {43834, 43836}
# Node 43836 has neighbors sets: {43834, 43835}
# Node 43837 has neighbors sets: {43838}
# Node 43838 has neighbors sets: {43837}
# Node 43845 has neighbors sets: {43846}
# Node 43846 has neighbors sets: {43845}
# Node 43854 has neighbors sets: {43855}
# Node 43855 has neighbors sets: {43854}
# Node 43864 has neighbors sets: {43865}
# Node 43865 has neighbors sets: {43864}
# Node 43983 has neighbors sets: {43984}
# Node 43984 has neighbors sets: {43983}
# Node 43986 has neighbors sets: {43987}
# Node 43987 has neighbors sets: {43986}
# Node 44003 has neighbors sets: {44004}
# Node 44004 has neighbors sets: {44003}
# Node 44015 has neighbors sets: {44016}
# Node 44016 has neighbors sets: {44015}
# Node 44018 has neighbors sets: {44019}
# Node 44019 has neighbors sets: {44018}
# Node 44022 has neighbors sets: {44023}
# Node 44023 has neighbors sets: {44022}
# Node 44028 has neighbors sets: {44029}
# Node 44029 has neighbors sets: {44028}
# Node 44035 has neighbors sets: {44036}
# Node 44036 has neighbors sets: {44035}
# Node 44039 has neighbors sets: {44040, 44041}
# Node 44040 has neighbors sets: {44041, 44039}
# Node 44041 has neighbors sets: {44040, 44039}
# Node 44046 has neighbors sets: {44047}
# Node 44047 has neighbors sets: {44046}
# Node 44067 has neighbors sets: {44068}
# Node 44068 has neighbors sets: {44067}
# Node 44073 has neighbors sets: {44074}
# Node 44074 has neighbors sets: {44073}
# Node 44078 has neighbors sets: {44079}
# Node 44079 has neighbors sets: {44078}
# Node 44083 has neighbors sets: {44084, 44085}
# Node 44084 has neighbors sets: {44083, 44085}
# Node 44085 has neighbors sets: {44083, 44084}
# Node 44133 has neighbors sets: {44134}
# Node 44134 has neighbors sets: {44133}
# Node 44156 has neighbors sets: {44157}
# Node 44157 has neighbors sets: {44156}
# Node 44208 has neighbors sets: {44209}
# Node 44209 has neighbors sets: {44208}
# Node 44266 has neighbors sets: {44267}
# Node 44267 has neighbors sets: {44266}
# Node 44271 has neighbors sets: {44272}
# Node 44272 has neighbors sets: {44271}
# Node 44296 has neighbors sets: {44297}
# Node 44297 has neighbors sets: {44296}
# Node 44307 has neighbors sets: {44308}
# Node 44308 has neighbors sets: {44307}
# Node 44319 has neighbors sets: {44320, 44321}
# Node 44320 has neighbors sets: {44321, 44319}
# Node 44321 has neighbors sets: {44320, 44319}
# Node 44333 has neighbors sets: {44334}
# Node 44334 has neighbors sets: {44333}
# Node 44336 has neighbors sets: {44337}
# Node 44337 has neighbors sets: {44336}
# Node 44347 has neighbors sets: {44348}
# Node 44348 has neighbors sets: {44347}
# Node 44350 has neighbors sets: {44351}
# Node 44351 has neighbors sets: {44350}
# Node 44353 has neighbors sets: {44354}
# Node 44354 has neighbors sets: {44353}
# Node 44409 has neighbors sets: {44410}
# Node 44410 has neighbors sets: {44409}
# Node 44422 has neighbors sets: {44423}
# Node 44423 has neighbors sets: {44422}
# Node 44446 has neighbors sets: {44447}
# Node 44447 has neighbors sets: {44446}
# Node 44470 has neighbors sets: {44471}
# Node 44471 has neighbors sets: {44470}
# Node 44474 has neighbors sets: {44475}
# Node 44475 has neighbors sets: {44474}
# Node 44477 has neighbors sets: {44478}
# Node 44478 has neighbors sets: {44477}
# Node 44500 has neighbors sets: {44501}
# Node 44501 has neighbors sets: {44500}
# Node 44509 has neighbors sets: {44510}
# Node 44510 has neighbors sets: {44509}
# Node 44511 has neighbors sets: {44512}
# Node 44512 has neighbors sets: {44511}
# Node 44539 has neighbors sets: {44540}
# Node 44540 has neighbors sets: {44539}
# Node 44563 has neighbors sets: {44564}
# Node 44564 has neighbors sets: {44563}
# Node 44617 has neighbors sets: {44618}
# Node 44618 has neighbors sets: {44617}
# Node 44640 has neighbors sets: {44641}
# Node 44641 has neighbors sets: {44640}
# Node 44678 has neighbors sets: {44679}
# Node 44679 has neighbors sets: {44678}
# Node 44680 has neighbors sets: {44681}
# Node 44681 has neighbors sets: {44680}
# Node 44701 has neighbors sets: {44702}
# Node 44702 has neighbors sets: {44701}
# Node 44712 has neighbors sets: {44713}
# Node 44713 has neighbors sets: {44712}
# Node 44737 has neighbors sets: {44738}
# Node 44738 has neighbors sets: {44737}
# Node 44751 has neighbors sets: {44752}
# Node 44752 has neighbors sets: {44751}
# Node 44778 has neighbors sets: {44779, 44780}
# Node 44779 has neighbors sets: {44778, 44780}
# Node 44780 has neighbors sets: {44778, 44779}
# Node 44787 has neighbors sets: {44788}
# Node 44788 has neighbors sets: {44787}
# Node 44811 has neighbors sets: {44812}
# Node 44812 has neighbors sets: {44811}
# Node 44833 has neighbors sets: {44834}
# Node 44834 has neighbors sets: {44833}
# Node 44887 has neighbors sets: {44888}
# Node 44888 has neighbors sets: {44887}
# Node 44915 has neighbors sets: {44916}
# Node 44916 has neighbors sets: {44915}
# Node 44936 has neighbors sets: {44937}
# Node 44937 has neighbors sets: {44936}
# Node 44942 has neighbors sets: {44943}
# Node 44943 has neighbors sets: {44942}
# Node 44947 has neighbors sets: {44948}
# Node 44948 has neighbors sets: {44947}
# Node 44967 has neighbors sets: {44968}
# Node 44968 has neighbors sets: {44967}
# Node 44989 has neighbors sets: {44990}
# Node 44990 has neighbors sets: {44989}
# Node 45008 has neighbors sets: {45009}
# Node 45009 has neighbors sets: {45008}
# Node 45021 has neighbors sets: {45022}
# Node 45022 has neighbors sets: {45021}
# Node 45026 has neighbors sets: {45027}
# Node 45027 has neighbors sets: {45026}
# Node 45045 has neighbors sets: {45046}
# Node 45046 has neighbors sets: {45045}
# Node 45062 has neighbors sets: {45063}
# Node 45063 has neighbors sets: {45062}
# Node 45186 has neighbors sets: {45187}
# Node 45187 has neighbors sets: {45186}
# Node 45448 has neighbors sets: {45449}
# Node 45449 has neighbors sets: {45448}
# Node 45704 has neighbors sets: {45705}
# Node 45705 has neighbors sets: {45704}
# Node 45889 has neighbors sets: {45890}
# Node 45890 has neighbors sets: {45889}
# Node 45892 has neighbors sets: {45893}
# Node 45893 has neighbors sets: {45892}

# %%
in_feats = graph.ndata['feature'].shape[1]
features = graph.ndata['feature']
num_classes = 2

lambda_1 = args.lambda_1

# set input graph
#三类边
relation1 = graph[graph.canonical_etypes[0]]
relation2 = graph[graph.canonical_etypes[1]]
relation3 = graph[graph.canonical_etypes[2]]


# build one-layer models
intra1 = IntraAgg(features, in_feats, cuda=args.cuda)
intra2 = IntraAgg(features, in_feats, cuda=args.cuda)
intra3 = IntraAgg(features, in_feats, cuda=args.cuda)
inter1 = InterAgg(features, in_feats, args.emb_size, adj_lists, [intra1, intra2, intra3], inter=args.inter,
                  step_size=args.step_size, cuda=args.cuda)

# %%
if args.run == 0:
    if homo:
        print("hello")
        model = CAREGNN_GAD(in_feats, h_feats, num_classes, graph,lambda_1)
    else:
        model = CAREGNN_GAD_Hetero(in_feats, h_feats, num_classes,lambda_1)
        train(model, graph, args)

else:
    final_mf1s, final_aucs = [], []
    for tt in range(args.run):
        if homo:
            #in_feats 特征点维度；h_feats：隐层维度；num_classes：节点分类数（nomal，anomaly）
            model = CAREGNN_GAD(in_feats, h_feats, num_classes, graph,inter1,lambda_1)
        else:
            model = CAREGNN_GAD_Hetero(in_feats, h_feats, num_classes, graph, inter1,lambda_1)
        mf1, auc = train(model, graph, args)
        final_mf1s.append(mf1)
        final_aucs.append(auc)
    final_mf1s = np.array(final_mf1s)
    final_aucs = np.array(final_aucs)
    # np.std :计算全局标准差
    print('MF1-mean: {:.2f}, MF1-std: {:.2f}, AUC-mean: {:.2f}, AUC-std: {:.2f}'.format(100 * np.mean(final_mf1s),
                                                                                            100 * np.std(final_mf1s),
                                                               100 * np.mean(final_aucs), 100 * np.std(final_aucs)))

# %%
adj_lists = [relation1, relation2, relation3]
nodes = graph.nodes()
for node in nodes:
    print(node)

# %%
adj_list[int(node)]

# %%
to_neighs = []
for adj_list in adj_lists:
    print(adj_list)
    to_neighs.append([set(adj_list[int(node)]) for node in nodes])

# %% [markdown]
# ##  Test
# ### 1. 按种类获取边（边存放在元组中，需要将元组转化为Tensor， 需要按边的种类，分别转化，不能一次将存放在元组中的边，转化为teosor）
# ### 2. ChebConv 模型需要边的输入类型为 二维Tensor

# %%
from dgl.data import FraudYelpDataset, FraudAmazonDataset
dataset = FraudAmazonDataset()
graph = dataset[0]
graph

# %%
graph = dgl.to_homogeneous(dataset[0], ndata=['feature', 'label', 'train_mask', 'val_mask', 'test_mask'])
graph = dgl.add_self_loop(graph)

# %%
graph.local_scope()

# %%
from dgl.data import FraudYelpDataset, FraudAmazonDataset
dataset = FraudYelpDataset()
graph = dataset[0]
graph

# %%
for relation in graph.canonical_etypes:
    print(relation)

# %%
edges_uvu = graph[relation].edges()
edge_index = torch.stack(edges_uvu)

# %%
#三类边
edges_upu = graph[graph.canonical_etypes[0]].edges()
edge_index_upu = torch.stack(edges_upu)
edges_usu = graph[graph.canonical_etypes[1]].edges()
edge_index_usu = torch.stack(edges_usu)
edges_uvu = graph[graph.canonical_etypes[2]].edges()
edge_index_uvu = torch.stack(edges_uvu)


# 合并连个Tensor，dim=1 按列合并
combined_tensor = torch.cat((edge_index_upu, edge_index_usu), dim=1)
edge_index = torch.cat((combined_tensor, edge_index_uvu), dim=1)

# %%
print("edge_index_upu.shape:",edge_index_upu.shape)
print("edge_index_usu.shape:",edge_index_usu.shape)
print("edge_index_uvu.shape:",edge_index_uvu.shape)
print("edge_index.shape:",edge_index.shape)

# %%
g1 = graph[graph.canonical_etypes[0]]

# %%
from dgl.data import FraudYelpDataset, FraudAmazonDataset
dataset = FraudAmazonDataset()
graph = dataset[0]

# %%
g_upu = graph[graph.canonical_etypes[0]]

# %%
g_upu.ndata['label'].shape

# %%
if homo:
    graph = dgl.to_homogeneous(dataset[0], ndata=['feature', 'label', 'train_mask', 'val_mask', 'test_mask'])
  
    graph = dgl.add_self_loop(graph)
                
    #三类边
    edges_upu = graph[graph.canonical_etypes[0]].edges()
    edge_index_upu = torch.stack(edges_upu)
    edges_usu = graph[graph.canonical_etypes[1]].edges()
    edge_index_usu = torch.stack(edges_usu)
    edges_uvu = graph[graph.canonical_etypes[2]].edges()
    edge_index_uvu = torch.stack(edges_uvu)
                
    # 合并连个Tensor，dim=1 按列合并
    combined_tensor = torch.cat((edge_index_upu, edge_index_usu), dim=1)
    edge_index = torch.cat((combined_tensor, edge_index_uvu), dim=1)

# %%
print(graph.canonical_etypes)
edge_index = graph.edges()
edge_index = torch.stack(edge_index)

# %% [markdown]
# ### 激活函数方面：nn.LeakyReLU(): LeakyReLU 是 ReLU 的一个变种，它允许负值通过一个小的斜率而不是将它们直接设为零。这个斜率是一个超参数，通常设置为一个小的正数，比如 0.01。这样做的目的是解决“ReLU 死亡神经元”问题，即某些神经元在训练过程中可能永远不会被激活，从而停止更新权重。LeakyReLU 在这种情况下可以提供更好的梯度流动，帮助网络更快地收敛。
